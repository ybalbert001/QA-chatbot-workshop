# %%
# %%capture

# !pip install tiktoken==0.3.3
# !pip install tqdm

# %%
# !pip install transformers

# %%
from tqdm import tqdm
import tiktoken
import requests
import logging
import os

# %%
tokenizer = tiktoken.get_encoding('cl100k_base')

# %%
DOC_DIR_PATH = './docs'

# %%
logger = logging.getLogger('sagemaker')
logger.setLevel(logging.DEBUG)
logger.addHandler(logging.StreamHandler())

# %%
def num_tokens_from_doc(doc: str) -> int:
    """
    Returns the number of tokens in a text string.
    """
    num_tokens = len(encoding.encode(doc))
    return num_tokens

# %%
CHUNK_SIZE = 256

# %%
def doc_iterator(dir_path: str):
    for root, _, filenames in os.walk(dir_path):
        for filename in filenames:
            file_path = os.path.join(root, filename)
            if os.path.isfile(file_path):
                with open(file_path, 'r') as file:
                    file_contents = file.read()
                    yield filename, file_contents

# %%
n_docs = 0
n_passages = 0

for doc_name, doc in tqdm(doc_iterator(DOC_DIR_PATH)):
    print(f"doc_name: {doc_name}")
    doc_id = doc_name.split('.')[0]
    tokens = tokenizer.encode(doc)
    chunks = []
    chunk_id = 1
    n_docs += 1
    for i in range(0, len(tokens), CHUNK_SIZE):
        chunk_tokens = tokens[i: i+CHUNK_SIZE]
        if not len(chunk_tokens) < 256:
            chunk = tokenizer.decode(chunk_tokens)
            with open(f'./chunks/{doc_id}_{chunk_id}', 'w') as f:
                f.write(chunk)
            chunk_id += 1
            n_passages += 1
logger.info(f'{n_docs} documents segmented into {n_passages} passages')
# Out:
# 1it [00:00,  6.97it/s]
# 1 documents segmented into 15 passages
# doc_name: Cleanroom_FAQ.txt

# %%
import json
import boto3

smr_client = boto3.client("sagemaker-runtime")
endpoint_name = "st-paraphrase-mpnet-base-v2-2023-04-14-04-17-29-625-endpoint"

def get_embedding(smr_client, text_input):
    parameters = {
      #"early_stopping": True,
      #"length_penalty": 2.0,
      "max_new_tokens": 50,
      "temperature": 0,
      "min_length": 10,
      "no_repeat_ngram_size": 2,
    }

    response_model = smr_client.invoke_endpoint(
                EndpointName=endpoint_name,
                Body=json.dumps(
                {
                    "inputs": [text_input],
                    "parameters": parameters
                }
                ),
                ContentType="application/json",
            )
    
    return response_model['Body'].read().decode('utf8')

# %%
for doc_name, doc in tqdm(doc_iterator(DOC_DIR_PATH)):
    if doc_name == "Cleanroom_FAQ.txt":
        lines = doc.splitlines()
        q_lines = [ line for line in lines if line.startswith('Question') ]
        a_lines = [ line for line in lines if line.startswith('Answer') ]
        print(get_embedding(smr_client, q_lines[1]))
# Out:
# 2it [00:00,  8.52it/s]
# b'{\n  "sentence_embeddings":[\n    [\n      0.01183790247887373,\n      0.0629643127322197,\n      -0.010602585040032864,\n      0.00385498208925128,\n      -0.08580745756626129,\n      0.06613323092460632,\n      0.06986038386821747,\n      0.06612421572208405,\n      -0.07077949494123459,\n      0.10049458593130112,\n      0.2561466693878174,\n      -0.05845275893807411,\n      0.060686249285936356,\n      0.06303957104682922,\n      -0.14984124898910522,\n      -0.014457563869655132,\n      0.029539579525589943,\n      0.10507740080356598,\n      -0.017891407012939453,\n      0.04731087386608124,\n      0.06511484086513519,\n      -0.11624763906002045,\n      -0.002014192519709468,\n      0.01344772893935442,\n      -0.024276848882436752,\n      -0.057371679693460464,\n      -0.0956144779920578,\n      -0.05627714842557907,\n      0.04029081016778946,\n      -0.05579474940896034,\n      -0.018311265856027603,\n      0.06787178665399551,\n      0.013893834315240383,\n      0.11880272626876831,\n      0.046943727880716324,\n      -0.037272293120622635,\n      0.10198863595724106,\n      0.08344967663288116,\n      -0.2111722230911255,\n      0.19191910326480865,\n      0.030343782156705856,\n      0.05580120533704758,\n      -0.01564328745007515,\n      0.03653666377067566,\n      -0.07569178193807602,\n      -0.011649977415800095,\n      0.08171840757131577,\n      -0.1893218606710434,\n      0.0595102533698082,\n      0.01208148431032896,\n      -0.029477916657924652,\n      0.21699006855487823,\n      -0.1859080195426941,\n      0.00012392054486554116,\n      0.10876982659101486,\n      -0.06092046573758125,\n      -0.09252474457025528,\n      0.03140009567141533,\n      0.22291789948940277,\n      -0.05086483433842659,\n      -0.028668083250522614,\n      -0.020749157294631004,\n      0.12948651611804962,\n      0.0002624392509460449,\n      -0.07964322715997696,\n      0.029091764241456985,\n      0.0068508777767419815,\n      -0.02414989471435547,\n      -0.0900430679321289,\n      -0.007183902896940708,\n      0.15193642675876617,\n      0.09448660165071487,\n      -0.031697195023298264,\n      -0.08002257347106934,\n      -0.0977124497294426,\n      -0.13868007063865662,\n      -0.09722279012203217,\n      -0.06542864441871643,\n      0.04265175387263298,\n      -0.011408043093979359,\n      -0.01715952530503273,\n      0.002608885057270527,\n      0.04184422269463539,\n      -0.07890308648347855,\n      -0.10729359090328217,\n      -0.07432063668966293,\n      0.021754058077931404,\n      0.06738990545272827,\n      -0.10949191451072693,\n      0.03760242834687233,\n      0.20484894514083862,\n      -0.01789143867790699,\n      -0.029627816751599312,\n      -0.03991684317588806,\n      0.04702269285917282,\n      0.022476140409708023,\n      0.13001982867717743,\n      0.08433188498020172,\n      0.10658517479896545,\n      0.21537621319293976,\n      0.17289723455905914,\n      -0.02961970865726471,\n      0.04863644763827324,\n      -0.03114328160881996,\n      0.10155072808265686,\n      -0.09369468688964844,\n      -0.1061297357082367,\n      -0.0805019736289978,\n      0.021806929260492325,\n      0.016251374036073685,\n      -0.10984423011541367,\n      -0.07043987512588501,\n      0.06621865928173065,\n      0.05980721488595009,\n      0.043504148721694946,\n      0.009106157347559929,\n      0.09767638891935349,\n      0.07603690773248672,\n      0.123321034014225,\n      -0.057486340403556824,\n      -0.14517414569854736,\n      -0.0002454221248626709,\n      -0.12798313796520233,\n      0.06703001260757446,\n      -0.1921108067035675,\n      0.001579875941388309,\n      -0.10259769856929779,\n      -0.03263349086046219,\n      -0.04324421286582947,\n      -0.125522643327713,\n      -0.061962973326444626,\n      -0.25366583466529846,\n      -0.0214545838534832,\n      -0.0032878220081329346,\n      0.004848884884268045,\n      -0.16295506060123444,\n      0.011396035552024841,\n      -0.04551621153950691,\n ...
